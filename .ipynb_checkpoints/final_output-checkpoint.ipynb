# %%
# 🔥 CLEAN + INSTALL (FULL COMPATIBLE SETUP)

# !pip uninstall -y tensorflow keras keras-nightly tf-keras numpy opencv-python matplotlib nibabel scikit-learn

# !pip install tensorflow==2.15.0 numpy==1.26.4 opencv-python==4.9.0.80 matplotlib==3.8.4 nibabel==5.2.1 scikit-learn==1.4.2
# Out:
# Found existing installation: tensorflow 2.20.0
# Uninstalling tensorflow-2.20.0:
#   Successfully uninstalled tensorflow-2.20.0
# Found existing installation: keras 3.11.3
# Uninstalling keras-3.11.3:
#   Successfully uninstalled keras-3.11.3
# WARNING: Skipping keras-nightly as it is not installed.
# WARNING: Skipping tf-keras as it is not installed.
# WARNING: Skipping numpy as it is not installed.
# WARNING: Skipping opencv-python as it is not installed.
# WARNING: Skipping matplotlib as it is not installed.
# WARNING: Skipping nibabel as it is not installed.
# WARNING: Skipping scikit-learn as it is not installed.
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.15.0 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.19.1, 2.20.0rc0, 2.20.0, 2.21.0rc0, 2.21.0rc1, 2.21.0)
# ERROR: No matching distribution found for tensorflow==2.15.0

# %%
import os
os._exit(0)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import tensorflow as tf
import numpy as np
import cv2
import nibabel as nib

print("TF:", tf.__version__)
print("NumPy:", np.__version__)
print("OpenCV:", cv2.__version__)
print("Nibabel:", nib.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import tensorflow as tf
# ----> 2 import numpy as np
#       3 import cv2
#       4 import nibabel as nib
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
import nibabel as nib

print("⏳ AI Models Load ho rahe hain, kripya wait karein...")

# --- TRICK: Bypassing the Keras 'batch_shape' bug by rebuilding architecture ---

def load_detector():
    """Model 1 (Tumor Detection) ka architecture"""
    model = Sequential([
        tf.keras.layers.Input(shape=(128, 128, 3)),
        Conv2D(32, (3,3), activation='relu'),
        MaxPooling2D((2,2)),
        Conv2D(64, (3,3), activation='relu'),
        MaxPooling2D((2,2)),
        Conv2D(128, (3,3), activation='relu'),
        MaxPooling2D((2,2)),
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    # Sirf weights load kar rahe hain, isse koi error nahi aayega
    model.load_weights('brain_tumor_detector_final.keras') 
    return model

def load_classifier():
    """Model 2 (Tumor Classification) ka architecture"""
    base_model = MobileNetV2(weights=None, include_top=False, input_shape=(224, 224, 3))
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'), 
        Dropout(0.5),
        Dense(4, activation='softmax')
    ])
    model.load_weights('tumor_classifier_final.keras')
    return model

# Global variables
detector_model = None
classifier_model = None

try:
    detector_model = load_detector()
    classifier_model = load_classifier()
    print("✅ Dono Models Successfully Load ho gaye (Bina kisi error ke)!")
except Exception as e:
    print(f"\n❌ Error loading weights: {e}")
    print("Kripya check karein ki 'brain_tumor_detector_best.keras' aur 'tumor_classifier_best.keras' current folder me hain ya nahi.")

CLASS_NAMES = ['Glioma Tumor', 'Meningioma Tumor', 'Healthy (No Tumor)', 'Pituitary Tumor']

# --- MAIN PIPELINE FUNCTION ---
def analyze_nifti_scan(nifti_path, slice_index=75):
    
    # NameError se bachne ke liye Safety Check
    if detector_model is None or classifier_model is None:
        print("❌ Models load nahi hue, isliye prediction aage nahi badh sakti.")
        return
        
    print(f"\nEvaluating NIfTI Image: {nifti_path}")
    
    # 1. Load NIfTI file using nibabel
    try:
        nifti_img = nib.load(nifti_path)
        img_data = nifti_img.get_fdata()
    except Exception as e:
        print(f"❌ Error loading .nii file: {e}")
        return

    # Check slice index limits
    if slice_index >= img_data.shape[2]:
         print(f"❌ Error: Slice index {slice_index} is out of bounds (Max is {img_data.shape[2]-1})")
         return

    # 2. Extract 2D slice
    slice_2d = img_data[:, :, slice_index]

    # Normalize and format to RGB
    if np.max(slice_2d) > 0:
        slice_2d_norm = (slice_2d / np.max(slice_2d)) * 255.0
    else:
        slice_2d_norm = slice_2d * 0
        
    slice_2d_norm = slice_2d_norm.astype(np.uint8)
    img_rgb = cv2.cvtColor(slice_2d_norm, cv2.COLOR_GRAY2RGB)

    # --- SHOW IMAGE ---
    plt.figure(figsize=(5, 5))
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(f"Input Scan (Slice {slice_index})", fontsize=14, fontweight='bold')
    plt.show()

    print("\n" + "="*40)
    print("🧠 FINAL AI ANALYSIS REPORT")
    print("="*40)

    # --- STEP 1: TUMOR DETECTION (Model 1) ---
    img_det = cv2.resize(img_rgb, (128, 128))
    img_det = img_det / 255.0  
    img_det = np.expand_dims(img_det, axis=0) 

    print("🔎 Scanning for Tumor...")
    det_prediction = detector_model.predict(img_det, verbose=0)[0][0]

    if det_prediction < 0.5:
        confidence = (1 - det_prediction) * 100
        print(f"✅ Result: HEALTHY BRAIN (No Tumor Detected)")
        print(f"📊 Confidence: {confidence:.2f}%")
        print("="*40)
        return 
    else:
        confidence = det_prediction * 100
        print(f"⚠️ Result: TUMOR DETECTED")
        print(f"📊 Detection Confidence: {confidence:.2f}%")
        
        # --- STEP 2: TUMOR CLASSIFICATION (Model 2) ---
        print("\n🔬 Analyzing Tumor Type...")
        
        img_class = cv2.resize(img_rgb, (224, 224))
        img_class = np.expand_dims(img_class, axis=0)
        img_class = preprocess_input(img_class) 

        class_prediction = classifier_model.predict(img_class, verbose=0)
        
        best_class_index = np.argmax(class_prediction, axis=1)[0]
        class_confidence = class_prediction[0][best_class_index] * 100
        predicted_tumor_type = CLASS_NAMES[best_class_index]

        print(f"🔴 Tumor Type: {predicted_tumor_type}")
        print(f"📊 Classification Confidence: {class_confidence:.2f}%")
        print("="*40)


# --- TEST THE PIPELINE ---
# Aapne jo path diya tha usko yahan laga diya hai
test_nifti_path = 'brats20_dataset/BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_001/BraTS20_Validation_001_flair.nii'

analyze_nifti_scan(test_nifti_path, slice_index=75)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 import matplotlib.pyplot as plt
#       5 import tensorflow as tf
# ----> 6 from tensorflow.keras.models import Sequential
#       7 from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
#       8 from tensorflow.keras.applications import MobileNetV2
#
# ModuleNotFoundError: No module named 'tensorflow.keras'
